# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
df['Year']=2025-df['Year']
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz    11           3.35           5.59       27000    Petrol
# 1        sx4    12           4.75           9.54       43000    Diesel
# 2       ciaz     8           7.25           9.85        6900    Petrol
# 3    wagon r    14           2.85           4.15        5200    Petrol
# 4      swift    11           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city     9           9.50          11.60       33988    Diesel
# 297     brio    10           4.00           5.90       60000    Petrol
# 298     city    16           3.35          11.00       87934    Petrol
# 299     city     8          11.50          12.50        9000    Diesel
# 300     brio     9           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
# to conver catagorial into numerical
pd.get_dummies(df)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Car_Name_800  \
# 0      11           3.35           5.59       27000      0             0
# 1      12           4.75           9.54       43000      0             0
# 2       8           7.25           9.85        6900      0             0
# 3      14           2.85           4.15        5200      0             0
# 4      11           4.60           6.87       42450      0             0
# ..    ...            ...            ...         ...    ...           ...
# 296     9           9.50          11.60       33988      0             0
# 297    10           4.00           5.90       60000      0             0
# 298    16           3.35          11.00       87934      0             0
# 299     8          11.50          12.50        9000      0             0
# 300     9           5.30           5.90        5464      0             0
#
#      Car_Name_Activa 3g  Car_Name_Activa 4g  Car_Name_Bajaj  ct 100  \
# ...

# %%
# to remove first colum on same data eg. from cng,diesel,petrol remove cng just show diesal,petrol
pd.get_dummies(df,drop_first=True)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  \
# 0      11           3.35           5.59       27000      0
# 1      12           4.75           9.54       43000      0
# 2       8           7.25           9.85        6900      0
# 3      14           2.85           4.15        5200      0
# 4      11           4.60           6.87       42450      0
# ..    ...            ...            ...         ...    ...
# 296     9           9.50          11.60       33988      0
# 297    10           4.00           5.90       60000      0
# 298    16           3.35          11.00       87934      0
# 299     8          11.50          12.50        9000      0
# 300     9           5.30           5.90        5464      0
#
#      Car_Name_Activa 3g  Car_Name_Activa 4g  Car_Name_Bajaj  ct 100  \
# 0                     0                   0                       0
# 1                     0                   0                       0
# ...

# %%
df.drop(columns=['Car_Name'],inplace=True)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0      11           3.35           5.59       27000    Petrol      Dealer
# 1      12           4.75           9.54       43000    Diesel      Dealer
# 2       8           7.25           9.85        6900    Petrol      Dealer
# 3      14           2.85           4.15        5200    Petrol      Dealer
# 4      11           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296     9           9.50          11.60       33988    Diesel      Dealer
# 297    10           4.00           5.90       60000    Petrol      Dealer
# 298    16           3.35          11.00       87934    Petrol      Dealer
# 299     8          11.50          12.50        9000    Diesel      Dealer
# 300     9           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0      11           3.35           5.59       27000      0                 0
# 1      12           4.75           9.54       43000      0                 1
# 2       8           7.25           9.85        6900      0                 0
# 3      14           2.85           4.15        5200      0                 0
# 4      11           4.60           6.87       42450      0                 1
# ..    ...            ...            ...         ...    ...               ...
# 296     9           9.50          11.60       33988      0                 1
# 297    10           4.00           5.90       60000      0                 0
# 298    16           3.35          11.00       87934      0                 0
# 299     8          11.50          12.50        9000      0                 1
# 300     9           5.30           5.90        5464      0                 0
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
x=df[['Year','Present_Price','Kms_Driven','Owner','Fuel_Type_Diesel','Fuel_Type_Petrol','Seller_Type_Individual','Transmission_Manual']]
y=df['Selling_Price']  #target column,dependent variable
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=32) #
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
# print(y_pred)
print(model.coef_)
print(model.intercept_)
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
y_pred1=model.predict([[10,3.5,33000,0,0,1,0,1]])
print(y_pred1)
# Out:
# (239, 8)
# (60, 8)
# (239,)
# (60,)
# [-3.89932433e-01  4.31097034e-01 -7.99421510e-06 -6.61257818e-01
#   2.34604992e+00  6.03664487e-01 -1.25034022e+00 -1.54880118e+00]
# 7.020858966675155
# 1.3961175233193035
# 0.8517312977783229
# [3.42142846]

# %%
df=pd.read_csv('auto-mpg.csv')
df.drop(columns=['car name'],inplace=True)

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df[df['horsepower']!='?']

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
df['horsepower']=df['horsepower'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int32
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin        392 non-null    int64
# dtypes: float64(3), int32(1), int64(4)
# memory usage: 26.0 KB

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
x=df[['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin']]
y=df['horsepower']#target column,dependent variable
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=32) #
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
# print(y_pred)
print(model.coef_)
print(model.intercept_)
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# (313, 8)
# (79, 8)
# (313,)
# (79,)
# [-5.32257856e-15 -4.17229007e-16 -1.84895564e-16  1.00000000e+00
#  -2.37036890e-17 -2.08837824e-17 -3.72601763e-16  7.73809916e-16]
# 2.2737367544323206e-13
# 1.0295533515431291e-27
# 1.0

# %%
df=pd.read_csv('Ice_cream selling data.csv')
df
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 0          -4.662263                41.842986
# 1          -4.316559                34.661120
# 2          -4.213985                39.383001
# 3          -3.949661                37.539845
# 4          -3.578554                32.284531
# 5          -3.455712                30.001138
# 6          -3.108440                22.635401
# 7          -3.081303                25.365022
# 8          -2.672461                19.226970
# 9          -2.652287                20.279679
# 10         -2.651498                13.275828
# 11         -2.288264                18.123991
# 12         -2.111870                11.218294
# 13         -1.818938                10.012868
# 14         -1.660348                12.615181
# 15         -1.326379                10.957731
# 16         -1.173123                 6.689123
# 17         -0.773330                 9.392969
# 18         -0.673753                 5.210163
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt
x=df[['Temperature (°C)']]
y=df['Ice Cream Sales (units)']#target column,dependent variable
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5) #
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
# print(y_pred)
print(model.coef_)
print(model.intercept_)
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred)
plt.show()
# Out:
# (39, 1)
# (10, 1)
# (39,)
# (10,)
# [-0.37037892]
# 15.830248665364017
# 196.81907644190096
# 0.05227955981613286
