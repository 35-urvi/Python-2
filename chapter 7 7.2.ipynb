# %%
# %%writefile tcpserver3.py
from socket import *
server=socket()
server.bind(('localhost',9000))
server.listen()
while(1):
    (client,add)=server.accept()
    rd=client.recv(1028).decode()
    print(rd)
    data="HTTP/1.1 200 OK\r\n"
    data+="content-type:text/html ; charset=utf-8\r\n"
    data+="\r\n"
    data+="<html><body>hello world</body></html>\r\n\r\n"
    client.send(data.encode())
server.close()
print("http://localhost:9000")
# Out:
# Overwriting tcpserver3.py

# %%
# %%writefile tcpclient3.py
from socket import *
client=socket()
client.connect(('localhost',9000))
request="GET/HTTP/1.1\r\n\host:localhost\r\n\r\n"
client.send(request.encode())
response=client.recv(1024).decode()
print(response)
client.close()
# Out:
# Overwriting tcpclient3.py

# %%
import requests,json
api_key='62cf32f721f746d389483bf535e084c3'
city_name=input('city: ')
request_url=f"""http://api.openweathermap.org/geo/1.0/direct?q={city_name}&appid={api_key}"""
response=requests.get(request_url)
cordinates=response.json()
print(cordinates)
lat=cordinates[0]['lat']
lon=cordinates[0]['lon']
print(lat)
print(lon)
# Out:
# city: ahmedabad
# [{'name': 'Ahmedabad', 'local_names': {'ta': 'அகமதாபாத்', 'he': 'אחמדאבאד', 'ar': 'أحمد آباد', 'ml': 'അഹമ്മദാബാദ്', 'gu': 'અમદાવાદ', 'pl': 'Ahmadabad', 'ur': 'احمد آباد', 'kn': 'ಅಹ್ಮದಾಬಾದ್', 'en': 'Ahmedabad', 'or': 'ଅହମଦାବାଦ', 'cs': 'Ahmadábád', 'pa': 'ਅਹਿਮਦਾਬਾਦ', 'oc': 'Ahmadabad', 'eo': 'Ahmadabado', 'te': 'అహ్మదాబాద్', 'zh': '艾哈迈达巴德', 'hi': 'अहमदाबाद', 'ru': 'Ахмадабад', 'ascii': 'Ahmedabad', 'ja': 'アフマダーバード', 'de': 'Ahmedabad', 'uk': 'Ахмедабад', 'feature_name': 'Ahmedabad', 'mr': 'अहमदाबाद'}, 'lat': 23.0216238, 'lon': 72.5797068, 'country': 'IN', 'state': 'Gujarat'}]
# 23.0216238
# 72.5797068

# %%
import requests,json
api_key='62cf32f721f746d389483bf535e084c3'
lat=23.0216238
lon=72.5797068
request_url=f"""https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"""
response=requests.get(request_url)
cordinates=response.json()
# print(cordinates)
print(json.dumps(cordinates,indent=5))
print('temprature:',cordinates['main']['temp'])
print('pressure:',cordinates['main']['pressure'])
print('humidity:',cordinates['main']['humidity'])
print('wind speed:',cordinates['wind'])
print('visiblity:',cordinates['visibility'])
# Out:
# {
#      "coord": {
#           "lon": 72.5797,
#           "lat": 23.0216
#      },
#      "weather": [
#           {
#                "id": 721,
#                "main": "Haze",
#                "description": "haze",
#                "icon": "50d"
#           }
#      ],
#      "base": "stations",
#      "main": {
#           "temp": 303.19,
#           "feels_like": 308.29,
#           "temp_min": 303.19,
#           "temp_max": 303.19,
#           "pressure": 999,
#           "humidity": 70,
#           "sea_level": 999,
#           "grnd_level": 994
#      },
#      "visibility": 2500,
#      "wind": {
#           "speed": 8.23,
#           "deg": 160
#      },
#      "clouds": {
#           "all": 75
#      },
#      "dt": 1748329496,
#      "sys": {
#           "type": 1,
#           "id": 9049,
#           "country": "IN",
#           "sunrise": 1748305496,
#           "sunset": 1748353743
#      },
#      "timezone": 19800,
#      "id": 1279233,
#      "name": "Ahmedabad",
# ...

# %%
import requests,json
api_key='62cf32f721f746d389483bf535e084c3'
lat=23.0216238
lon=72.5797068
request_url=f"""http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={api_key}"""
response=requests.get(request_url)
cordinates=response.json()
# print(cordinates)
print(json.dumps(cordinates,indent=5))
print('aqi:',cordinates['list'][0]['main']['aqi'])
# Out:
# {
#      "coord": {
#           "lon": 72.5797,
#           "lat": 23.0216
#      },
#      "list": [
#           {
#                "main": {
#                     "aqi": 3
#                },
#                "components": {
#                     "co": 122,
#                     "no": 0.05,
#                     "no2": 1.27,
#                     "o3": 83.62,
#                     "so2": 2.47,
#                     "pm2_5": 25.02,
#                     "pm10": 80.36,
#                     "nh3": 1.39
#                },
#                "dt": 1748330182
#           }
#      ]
# }
# aqi: 3

# %%
import requests,json
import pandas as pd
api_key='62cf32f721f746d389483bf535e084c3'
lat=23.0216238
lon=72.5797068
request_url=f"""http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"""
response=requests.get(request_url)
cordinates=response.json()
# print(cordinates)
# print(json.dumps(cordinates,indent=5))
d={'date_time':[] ,'temp':[],'pressure':[],'humidity':[],'weather':[]}
for i in cordinates['list']:
    d['date_time'].append(i['dt_txt'])
    d['temp'].append(i['main']['temp'])
    d['pressure'].append(i['main']['pressure'])
    d['humidity'].append(i['main']['humidity'])
    d['weather'].append(i['weather'][0]['description'])
df=pd.DataFrame(d)
print(df)
# Out:
#               date_time    temp  pressure  humidity           weather
# 0   2025-05-27 09:00:00  305.19       997        62     broken clouds
# 1   2025-05-27 12:00:00  308.25       996        50     broken clouds
# 2   2025-05-27 15:00:00  308.90       996        47        light rain
# 3   2025-05-27 18:00:00  306.59       999        51        light rain
# 4   2025-05-27 21:00:00  304.23       998        61   overcast clouds
# 5   2025-05-28 00:00:00  303.01       999        67   overcast clouds
# 6   2025-05-28 03:00:00  304.43      1001        61   overcast clouds
# 7   2025-05-28 06:00:00  310.51       999        35     broken clouds
# 8   2025-05-28 09:00:00  315.18       996        23     broken clouds
# 9   2025-05-28 12:00:00  315.50       994        22     broken clouds
# 10  2025-05-28 15:00:00  308.33       998        46   overcast clouds
# 11  2025-05-28 18:00:00  306.74       998        50   overcast clouds
# ...

# %%
import requests,json
import pandas as pd
api_key='62cf32f721f746d389483bf535e084c3'
lat=23.0216238
lon=72.5797068
request_url=f"""http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat={lat}&lon={lon}&appid={api_key}"""
response=requests.get(request_url)
cordinates=response.json()
# print(cordinates)
# print(json.dumps(cordinates,indent=5))
d={'date_time':[] ,'co':[],'no':[],'no2':[],'o3':[],'so2':[],'pm2_5':[],'pm10':[],'nh3':[]}
for i in cordinates['list']:
    d['date_time'].append(i['dt'])
    d['co'].append(i['components']['co'])
    d['no'].append(i['components']['no'])
    d['no2'].append(i['components']['no2'])
    d['o3'].append(i['components']['o3'])
    d['so2'].append(i['components']['so2'])
    d['pm2_5'].append(i['components']['pm2_5'])
    d['pm10'].append(i['components']['pm10'])
    d['nh3'].append(i['components']['nh3'])

df=pd.DataFrame(d)
# print(df)
df
# Out:
#      date_time      co    no   no2     o3   so2  pm2_5    pm10   nh3
# 0   1748329200  122.00  0.05  1.27  83.62  2.47  25.02   80.36  1.39
# 1   1748332800  124.51  0.05  1.22  85.44  2.20  24.13   78.50  1.72
# 2   1748336400  125.35  0.05  1.14  86.99  2.04  22.84   74.18  1.89
# 3   1748340000  138.55  0.05  1.08  93.39  1.93  24.35   73.97  2.87
# 4   1748343600  151.66  0.05  1.18  98.02  1.92  26.59   75.17  3.82
# ..         ...     ...   ...   ...    ...   ...    ...     ...   ...
# 91  1748656800   97.05  0.04  1.29  58.24  1.02  27.68  108.49  0.57
# 92  1748660400   98.50  0.15  1.32  59.71  1.16  26.91  105.68  0.54
# 93  1748664000   99.12  0.16  1.00  66.89  1.23  25.73  101.47  0.43
# 94  1748667600   99.08  0.13  0.75  74.14  1.28  24.68   96.02  0.39
# 95  1748671200   98.92  0.11  0.63  79.81  1.31  24.50   93.05  0.34
#
# [96 rows x 9 columns]
